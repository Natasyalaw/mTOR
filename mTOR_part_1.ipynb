# %% [markdown]
# ## **Installing Libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.4.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.4.26)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.8)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.7 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.2 MB/s eta 0:00:00
# Downloading cattrs-24.1.3-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.6 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.3 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target Protein (mTOR)**

# %% [markdown]
# ## **Target search for serine/threonine-protein kinase mTORn**

# %%
# Target search for Serine/threonine-protein kinase mTOR
target = new_client.target
target_query = target.search('Serine/threonine-protein kinase mTOR')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#      cross_references           organism  \
# 0                  []       Homo sapiens
# 1                  []  Rattus norvegicus
# 2                  []       Mus musculus
# 3                  []       Mus musculus
# 4                  []       Homo sapiens
# ...               ...                ...
# 9995               []       Homo sapiens
# 9996               []       Mus musculus
# 9997               []  Rattus norvegicus
# 9998               []       Mus musculus
# 9999               []       Homo sapiens
#
#                                            pref_name  score  \
# 0               Serine/threonine-protein kinase mTOR   30.0
# 1               Serine/threonine-protein kinase mTOR   30.0
# 2               Serine/threonine-protein kinase mTOR   30.0
# 3                                             mTORC1   30.0
# 4                                        DEPTOR/mTOR   26.0
# ...                                              ...    ...
# 9995                   Integrin alpha4/beta7 complex    0.0
# 9996                      Tryptophan 5-hydroxylase 1    0.0
# 9997  Soluble guanylate cyclase alpha1/beta1 complex    0.0
# 9998      VHL-Nicotinamide phosphoribosyltransferase    0.0
# 9999                                       NRF2-MAFG    0.0
#
#       species_group_flag target_chembl_id  \
# 0                  False       CHEMBL2842
# 1                  False    CHEMBL1075134
# 2                  False    CHEMBL1255165
# 3                  False    CHEMBL5465384
# 4                  False    CHEMBL4523674
# ...                  ...              ...
# 9995               False    CHEMBL5465395
# 9996               False    CHEMBL5465551
# 9997               False    CHEMBL5482988
# 9998               False    CHEMBL5482989
# 9999               False    CHEMBL5483087
#
#                                       target_components  \
# 0     [{'accession': 'P42345', 'component_descriptio...
# 1     [{'accession': 'P42346', 'component_descriptio...
# 2     [{'accession': 'Q9JLN9', 'component_descriptio...
# 3     [{'accession': 'Q9JLN9', 'component_descriptio...
# 4     [{'accession': 'P42345', 'component_descriptio...
# ...                                                 ...
# 9995  [{'accession': 'P48169', 'component_descriptio...
# 9996  [{'accession': 'P17532', 'component_descriptio...
# 9997  [{'accession': 'P19686', 'component_descriptio...
# 9998  [{'accession': 'Q99KQ4', 'component_descriptio...
# 9999  [{'accession': 'Q16236', 'component_descriptio...
#
#                       target_type   tax_id
# 0                  SINGLE PROTEIN   9606.0
# 1                  SINGLE PROTEIN  10116.0
# 2                  SINGLE PROTEIN  10090.0
# 3                 PROTEIN COMPLEX  10090.0
# 4     PROTEIN-PROTEIN INTERACTION   9606.0
# ...                           ...      ...
# 9995              PROTEIN COMPLEX   9606.0
# 9996               SINGLE PROTEIN  10090.0
# 9997              PROTEIN COMPLEX  10116.0
# 9998  PROTEIN-PROTEIN INTERACTION  10090.0
# 9999              PROTEIN COMPLEX   9606.0
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## **Select and retrieve bioactivity data for serine/threonine-protein kinase mTOR (first entry)**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2842'

# %% [markdown]
# Here, we will retrieve only bioactivity data for serine/threonine-protein kinase mTOR (CHEMBL2842) that are reported as IC50 values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')
df = pd.DataFrame.from_dict(res)

df_filtered = df[(df['type'] == 'IC50') & ((df['units'] == 'nM')  |  (df ['units'] == 'uM'))]

df_filtered
# Out:
#      action_type activity_comment  activity_id  \
# 12          None             None      1410291
# 13          None             None      1412283
# 14          None             None      1412288
# 15          None             None      1412303
# 16          None             None      1459738
# ...          ...              ...          ...
# 5264        None             None     25755796
# 5265        None             None     25777959
# 5266        None             None     25782764
# 5267        None             None     25786790
# 5268        None             None     25787569
#
#                                     activity_properties assay_chembl_id  \
# 12                                                   []    CHEMBL830918
# 13                                                   []    CHEMBL830918
# 14                                                   []    CHEMBL830918
# 15                                                   []    CHEMBL830918
# 16                                                   []    CHEMBL830270
# ...                                                 ...             ...
# 5264  [{'comments': None, 'relation': None, 'result_...   CHEMBL5446092
# 5265  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5477195
# 5266  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5468047
# 5267  [{'comments': None, 'relation': None, 'result_...   CHEMBL5473708
# 5268  [{'comments': None, 'relation': None, 'result_...   CHEMBL5474448
#
#                                       assay_description assay_type  \
# 12    Inhibition of mTOR protein isolated from HeLa ...          B
# 13    Inhibition of mTOR protein isolated from HeLa ...          B
# 14    Inhibition of mTOR protein isolated from HeLa ...          B
# 15    Inhibition of mTOR protein isolated from HeLa ...          B
# 16     Inhibition of Mammalian target of Rapamycin mTOR          B
# ...                                                 ...        ...
# 5264  Affinity Biochemical interaction: (Dissociatio...          B
# 5265  Selectivity interaction (SelectScreen Kinase P...          B
# 5266  Selectivity interaction (Enzyme panel (AstraZe...          B
# 5267  Selectivity interaction (Kinase panel (KinaseG...          B
# 5268  Selectivity interaction (Kinase panel (antibod...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 12                      None                   None  BAO_0000190  ...
# 13                      None                   None  BAO_0000190  ...
# 14                      None                   None  BAO_0000190  ...
# 15                      None                   None  BAO_0000190  ...
# 16                      None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 5264                    None                   None  BAO_0000190  ...
# 5265                    None                   None  BAO_0000190  ...
# 5266                    None                   None  BAO_0000190  ...
# 5267                    None                   None  BAO_0000190  ...
# 5268                    None                   None  BAO_0000190  ...
#
#      target_organism                      target_pref_name target_tax_id  \
# 12      Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 13      Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 14      Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 15      Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 16      Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# ...              ...                                   ...           ...
# 5264    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5265    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5266    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5267    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5268    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
#
#      text_value  toid  type units    uo_units upper_value value
# 12         None  None  IC50    uM  UO_0000065        None   4.8
# 13         None  None  IC50    uM  UO_0000065        None   2.5
# 14         None  None  IC50    uM  UO_0000065        None   6.4
# 15         None  None  IC50    uM  UO_0000065        None   5.3
# 16         None  None  IC50    uM  UO_0000065        None   1.7
# ...         ...   ...   ...   ...         ...         ...   ...
# 5264       None  None  IC50    nM  UO_0000065        None  0.19
# 5265       None  None  IC50    nM  UO_0000065        None  4.32
# 5266       None  None  IC50    uM  UO_0000065        None   8.0
# 5267       None  None  IC50    uM  UO_0000065        None   9.0
# 5268       None  None  IC50    uM  UO_0000065        None   9.1
#
# [5136 rows x 46 columns]

# %%
df_filtered.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file .

# %% [markdown]
# ## **Data processing**

# %% [markdown]
# If any compounds has missing value for the standard_value and canonical_smiles column then drop it.

# %%
import pandas as pd

df_filtered = pd.read_csv('bioactivity_data.csv')
df2 = df_filtered[df_filtered.standard_value.notna()]
df2 = df2[df2.canonical_smiles.notna()]
df2
# Out:
#      action_type activity_comment  activity_id  \
# 0            NaN              NaN      1410291
# 1            NaN              NaN      1412283
# 2            NaN              NaN      1412288
# 3            NaN              NaN      1412303
# 4            NaN              NaN      1459738
# ...          ...              ...          ...
# 5131         NaN              NaN     25755796
# 5132         NaN              NaN     25777959
# 5133         NaN              NaN     25782764
# 5134         NaN              NaN     25786790
# 5135         NaN              NaN     25787569
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL830918
# 1                                                    []    CHEMBL830918
# 2                                                    []    CHEMBL830918
# 3                                                    []    CHEMBL830918
# 4                                                    []    CHEMBL830270
# ...                                                 ...             ...
# 5131  [{'comments': None, 'relation': None, 'result_...   CHEMBL5446092
# 5132  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5477195
# 5133  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5468047
# 5134  [{'comments': None, 'relation': None, 'result_...   CHEMBL5473708
# 5135  [{'comments': None, 'relation': None, 'result_...   CHEMBL5474448
#
#                                       assay_description assay_type  \
# 0     Inhibition of mTOR protein isolated from HeLa ...          B
# 1     Inhibition of mTOR protein isolated from HeLa ...          B
# 2     Inhibition of mTOR protein isolated from HeLa ...          B
# 3     Inhibition of mTOR protein isolated from HeLa ...          B
# 4      Inhibition of Mammalian target of Rapamycin mTOR          B
# ...                                                 ...        ...
# 5131  Affinity Biochemical interaction: (Dissociatio...          B
# 5132  Selectivity interaction (SelectScreen Kinase P...          B
# 5133  Selectivity interaction (Enzyme panel (AstraZe...          B
# 5134  Selectivity interaction (Kinase panel (KinaseG...          B
# 5135  Selectivity interaction (Kinase panel (antibod...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 0                         NaN                     NaN  BAO_0000190  ...
# 1                         NaN                     NaN  BAO_0000190  ...
# 2                         NaN                     NaN  BAO_0000190  ...
# 3                         NaN                     NaN  BAO_0000190  ...
# 4                         NaN                     NaN  BAO_0000190  ...
# ...                       ...                     ...          ...  ...
# 5131                      NaN                     NaN  BAO_0000190  ...
# 5132                      NaN                     NaN  BAO_0000190  ...
# 5133                      NaN                     NaN  BAO_0000190  ...
# 5134                      NaN                     NaN  BAO_0000190  ...
# 5135                      NaN                     NaN  BAO_0000190  ...
#
#      target_organism                      target_pref_name target_tax_id  \
# 0       Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 1       Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 2       Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 3       Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 4       Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# ...              ...                                   ...           ...
# 5131    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5132    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5133    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5134    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5135    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
#
#      text_value toid  type units    uo_units upper_value value
# 0           NaN  NaN  IC50    uM  UO_0000065         NaN  4.80
# 1           NaN  NaN  IC50    uM  UO_0000065         NaN  2.50
# 2           NaN  NaN  IC50    uM  UO_0000065         NaN  6.40
# 3           NaN  NaN  IC50    uM  UO_0000065         NaN  5.30
# 4           NaN  NaN  IC50    uM  UO_0000065         NaN  1.70
# ...         ...  ...   ...   ...         ...         ...   ...
# 5131        NaN  NaN  IC50    nM  UO_0000065         NaN  0.19
# 5132        NaN  NaN  IC50    nM  UO_0000065         NaN  4.32
# 5133        NaN  NaN  IC50    uM  UO_0000065         NaN  8.00
# 5134        NaN  NaN  IC50    uM  UO_0000065         NaN  9.00
# 5135        NaN  NaN  IC50    uM  UO_0000065         NaN  9.10
#
# [5135 rows x 46 columns]

# %% [markdown]
# Delete duplicate rows with the same normalized SMILES value, and then calculate the number of unique normalized SMILES values.

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 5107  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 5108  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 5109  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 5133                                                NaN              NaN
# 5134                                                NaN              NaN
#
#       activity_id                                activity_properties  \
# 0         1410291                                                 []
# 1         1412283                                                 []
# 2         1412288                                                 []
# 3         1412303                                                 []
# 4         1459738                                                 []
# ...           ...                                                ...
# 5107     25668044  [{'comments': None, 'relation': '=', 'result_f...
# 5108     25683584  [{'comments': None, 'relation': '=', 'result_f...
# 5109     25683585  [{'comments': None, 'relation': '=', 'result_f...
# 5133     25782764  [{'comments': None, 'relation': '=', 'result_f...
# 5134     25786790  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL830918  Inhibition of mTOR protein isolated from HeLa ...
# 1       CHEMBL830918  Inhibition of mTOR protein isolated from HeLa ...
# 2       CHEMBL830918  Inhibition of mTOR protein isolated from HeLa ...
# 3       CHEMBL830918  Inhibition of mTOR protein isolated from HeLa ...
# 4       CHEMBL830270   Inhibition of Mammalian target of Rapamycin mTOR
# ...              ...                                                ...
# 5107   CHEMBL5375563  Inhibition of recombinant human GST-tagged mTO...
# 5108   CHEMBL5380301  Inhibition of mTOR (unknown origin) incubated ...
# 5109   CHEMBL5380301  Inhibition of mTOR (unknown origin) incubated ...
# 5133   CHEMBL5468047  Selectivity interaction (Enzyme panel (AstraZe...
# 5134   CHEMBL5473708  Selectivity interaction (Kinase panel (KinaseG...
#
#      assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0             B                      NaN                     NaN  BAO_0000190
# 1             B                      NaN                     NaN  BAO_0000190
# 2             B                      NaN                     NaN  BAO_0000190
# 3             B                      NaN                     NaN  BAO_0000190
# 4             B                      NaN                     NaN  BAO_0000190
# ...         ...                      ...                     ...          ...
# 5107          B                      NaN                     NaN  BAO_0000190
# 5108          B                      NaN                     NaN  BAO_0000190
# 5109          B                      NaN                     NaN  BAO_0000190
# 5133          B                      NaN                     NaN  BAO_0000190
# 5134          B                      NaN                     NaN  BAO_0000190
#
#       ... target_organism                      target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 1     ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 2     ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 3     ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 4     ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# ...   ...             ...                                   ...           ...
# 5107  ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5108  ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5109  ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5133  ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
# 5134  ...    Homo sapiens  Serine/threonine-protein kinase mTOR          9606
#
#      text_value toid  type units    uo_units upper_value value
# 0           NaN  NaN  IC50    uM  UO_0000065         NaN  4.80
# 1           NaN  NaN  IC50    uM  UO_0000065         NaN  2.50
# 2           NaN  NaN  IC50    uM  UO_0000065         NaN  6.40
# 3           NaN  NaN  IC50    uM  UO_0000065         NaN  5.30
# 4           NaN  NaN  IC50    uM  UO_0000065         NaN  1.70
# ...         ...  ...   ...   ...         ...         ...   ...
# 5107        NaN  NaN  IC50    nM  UO_0000065         NaN  7.10
# 5108        NaN  NaN  IC50    uM  UO_0000065         NaN  0.83
# 5109        NaN  NaN  IC50    uM  UO_0000065         NaN  2.85
# 5133        NaN  NaN  IC50    uM  UO_0000065         NaN  8.00
# 5134        NaN  NaN  IC50    uM  UO_0000065         NaN  9.00
#
# [4572 rows x 46 columns]

# %% [markdown]
# Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL435507                CC1CN(c2cc(=O)c3ccc4ccccc4c3o2)CCO1
# 1           CHEMBL98350              O=c1cc(N2CCOCC2)oc2c(-c3ccccc3)cccc12
# 2          CHEMBL104468                   O=c1cc(N2CCOCC2)oc2c1ccc1ccccc12
# 3          CHEMBL179242                   O=c1cc(N2CCOCC2)nc2c3ccccc3ccn12
# 4          CHEMBL188678   O=c1cc(N2CCOCC2)oc2c(-c3cccc4c3sc3ccccc34)cccc12
# ...                 ...                                                ...
# 5107      CHEMBL5433283  Cc1cccc2c(-c3ncc4c(n3)N3CCOC[C@@]3(C)C(=O)N4C3...
# 5108      CHEMBL5437417  N#Cc1c(-c2ccc(Cl)cc2)nc(N/N=C/c2cccc(Cl)c2)nc1...
# 5109      CHEMBL5432408  N#Cc1c(-c2ccc(Cl)cc2)nc(N/N=C/c2cccc(O)c2)nc1N...
# 5133      CHEMBL2165191  Cc1cc([C@@H](C)Nc2ccccc2C(=O)O)c2nc(N3CCOCC3)c...
# 5134      CHEMBL1852688  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...
#
#       standard_value
# 0             4800.0
# 1             2500.0
# 2             6400.0
# 3             5300.0
# 4             1700.0
# ...              ...
# 5107             7.1
# 5108           830.0
# 5109          2850.0
# 5133          8000.0
# 5134          9000.0
#
# [4572 rows x 3 columns]

# %% [markdown]
# ## **Labeling compounds as either being active, inactive or intermediate**

# %%
bioactivity_threshold = []
for i in df3.standard_value:
  if float(i) >= 1000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 100:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

df3 = df3.reset_index(drop=True)

bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL435507                CC1CN(c2cc(=O)c3ccc4ccccc4c3o2)CCO1
# 1           CHEMBL98350              O=c1cc(N2CCOCC2)oc2c(-c3ccccc3)cccc12
# 2          CHEMBL104468                   O=c1cc(N2CCOCC2)oc2c1ccc1ccccc12
# 3          CHEMBL179242                   O=c1cc(N2CCOCC2)nc2c3ccccc3ccn12
# 4          CHEMBL188678   O=c1cc(N2CCOCC2)oc2c(-c3cccc4c3sc3ccccc34)cccc12
# ...                 ...                                                ...
# 4567      CHEMBL5433283  Cc1cccc2c(-c3ncc4c(n3)N3CCOC[C@@]3(C)C(=O)N4C3...
# 4568      CHEMBL5437417  N#Cc1c(-c2ccc(Cl)cc2)nc(N/N=C/c2cccc(Cl)c2)nc1...
# 4569      CHEMBL5432408  N#Cc1c(-c2ccc(Cl)cc2)nc(N/N=C/c2cccc(O)c2)nc1N...
# 4570      CHEMBL2165191  Cc1cc([C@@H](C)Nc2ccccc2C(=O)O)c2nc(N3CCOCC3)c...
# 4571      CHEMBL1852688  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...
#
#       standard_value         class
# 0             4800.0      inactive
# 1             2500.0      inactive
# 2             6400.0      inactive
# 3             5300.0      inactive
# 4             1700.0      inactive
# ...              ...           ...
# 4567             7.1        active
# 4568           830.0  intermediate
# 4569          2850.0      inactive
# 4570          8000.0      inactive
# 4571          9000.0      inactive
#
# [4572 rows x 4 columns]

# %% [markdown]
# Delete rows containing intermediate

# %%
df5 = df4[df4['class'] != 'intermediate']
df5 = df5.sort_values('standard_value')
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 2160      CHEMBL3645910  CCc1ncnc(-c2cc(F)c(C(=O)N3CCN4CCC[C@H]4C3)c(Cl...
# 89         CHEMBL558955  COC(=O)N1CCC(n2ncc3c(N4CCOCC4)nc(-c4ccc(NC(=O)...
# 167        CHEMBL585480  CCn1ncc2c(N3CC4CCC(C3)O4)nc(-c3ccc(NC(=O)Nc4cc...
# 148        CHEMBL566004  CCn1ncc2c(N3CC4CCC(C3)O4)nc(-c3ccc(NC(=O)Nc4cc...
# 497       CHEMBL1098245  COC(=O)N1CCC(n2ncc3c(N4CCOCC4)nc(-c4ccc(NC(=O)...
# ...                 ...                                                ...
# 674       CHEMBL1241864      Nc1ncnc2c1c(-c1ccc3[nH]c(=O)ccc3c1)nn2C1CCCC1
# 568       CHEMBL1241482   Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2Cc1ocnc1-c1ccccc1
# 781       CHEMBL1631890                  Fc1cc(F)cc(C#Cc2n[nH]c3ccccc23)c1
# 827           CHEMBL113                         Cn1c(=O)c2c(ncn2C)n(C)c1=O
# 1108      CHEMBL2087479  CS(=O)(=O)N1CCN(Cc2cn3cc(-c4cnc(N)nc4C(F)(F)F)...
#
#       standard_value     class
# 2160            0.07    active
# 89              0.08    active
# 167             0.10    active
# 148             0.10    active
# 497             0.10    active
# ...              ...       ...
# 674        100000.00  inactive
# 568        100000.00  inactive
# 781        200000.00  inactive
# 827        400000.00  inactive
# 1108     10000000.00  inactive
#
# [3649 rows x 4 columns]

# %%
counts = df5['class'].value_counts()
active_count = counts['active']
inactive_count = counts['inactive']

print("Active count:", active_count)
print("Inactive count:", inactive_count)
# Out:
# Active count: 2468
# Inactive count: 1181

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Serine_threonine-protein_Kinase_mTOR.csv', index=False)
from google.colab import files
files.download('Serine_threonine-protein_Kinase_mTOR.csv')
